# %%
import requests
import os
import urllib
import csv
import glob
import pandas as pd
import numpy as np

# %%
movies_df = pd.read_csv("..\Datasets\MoviesOnStreamingPlatforms_updated.csv", dtype='unicode', encoding='utf8' )    
movies_df.head()
# Out:
#   Unnamed: 0 ID                           Title  Year  Age IMDb  \
# 0          0  1                       Inception  2010  13+  8.8
# 1          1  2                      The Matrix  1999  18+  8.7
# 2          2  3          Avengers: Infinity War  2018  13+  8.5
# 3          3  4              Back to the Future  1985   7+  8.5
# 4          4  5  The Good, the Bad and the Ugly  1966  18+  8.8
#
#   Rotten Tomatoes Netflix Hulu Prime Video Disney+ Type  \
# 0             87%       1    0           0       0    0
# 1             87%       1    0           0       0    0
# 2             84%       1    0           0       0    0
# 3             96%       1    0           0       0    0
# 4             97%       1    0           1       0    0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language Runtime
# 0  United States,United Kingdom  English,Japanese,French     148
# 1                 United States                  English     136
# 2                 United States                  English     149
# 3                 United States                  English     116
# 4      Italy,Spain,West Germany                  Italian     161

# %%
movies_df['movies']= 'Movie'

# %%
movies_df1 =movies_df.drop('Unnamed: 0',axis=1)
movies_df1.head()
movies_cleaned= movies_df1.drop('ID',axis=1)
movies_cleaned.head()
# Out:
#                             Title  Year  Age IMDb Rotten Tomatoes Netflix  \
# 0                       Inception  2010  13+  8.8             87%       1
# 1                      The Matrix  1999  18+  8.7             87%       1
# 2          Avengers: Infinity War  2018  13+  8.5             84%       1
# 3              Back to the Future  1985   7+  8.5             96%       1
# 4  The Good, the Bad and the Ugly  1966  18+  8.8             97%       1
#
#   Hulu Prime Video Disney+ Type                       Directors  \
# 0    0           0       0    0               Christopher Nolan
# 1    0           0       0    0  Lana Wachowski,Lilly Wachowski
# 2    0           0       0    0         Anthony Russo,Joe Russo
# 3    0           0       0    0                 Robert Zemeckis
# 4    0           1       0    0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language Runtime movies
# 0  English,Japanese,French     148  Movie
# 1                  English     136  Movie
# 2                  English     149  Movie
# 3                  English     116  Movie
# 4                  Italian     161  Movie

# %%
shows_df1 = pd.read_csv("../Datasets/tv_shows.csv", dtype='unicode', encoding='utf8' )  
shows_df1.head()
# Out:
#   Unnamed: 0             Title  Year  Age IMDb Rotten Tomatoes Netflix Hulu  \
# 0          0      Breaking Bad  2008  18+  9.5             96%       1    0
# 1          1   Stranger Things  2016  16+  8.8             93%       1    0
# 2          2       Money Heist  2017  18+  8.4             91%       1    0
# 3          3          Sherlock  2010  16+  9.1             78%       1    0
# 4          4  Better Call Saul  2015  18+  8.7             97%       1    0
#
#   Prime Video Disney+ type
# 0           0       0    1
# 1           0       0    1
# 2           0       0    1
# 3           0       0    1
# 4           0       0    1

# %%
shows_df2=shows_df1.drop('Unnamed: 0',axis=1)
shows_df2.head()
# Out:
#               Title  Year  Age IMDb Rotten Tomatoes Netflix Hulu Prime Video  \
# 0      Breaking Bad  2008  18+  9.5             96%       1    0           0
# 1   Stranger Things  2016  16+  8.8             93%       1    0           0
# 2       Money Heist  2017  18+  8.4             91%       1    0           0
# 3          Sherlock  2010  16+  9.1             78%       1    0           0
# 4  Better Call Saul  2015  18+  8.7             97%       1    0           0
#
#   Disney+ type
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
shows_df2['shows']= 'TV'
shows_df2.head()
# Out:
#               Title  Year  Age IMDb Rotten Tomatoes Netflix Hulu Prime Video  \
# 0      Breaking Bad  2008  18+  9.5             96%       1    0           0
# 1   Stranger Things  2016  16+  8.8             93%       1    0           0
# 2       Money Heist  2017  18+  8.4             91%       1    0           0
# 3          Sherlock  2010  16+  9.1             78%       1    0           0
# 4  Better Call Saul  2015  18+  8.7             97%       1    0           0
#
#   Disney+ type shows
# 0       0    1    TV
# 1       0    1    TV
# 2       0    1    TV
# 3       0    1    TV
# 4       0    1    TV

# %%
movies_cleaned.head()
# Out:
#                             Title  Year  Age IMDb Rotten Tomatoes Netflix  \
# 0                       Inception  2010  13+  8.8             87%       1
# 1                      The Matrix  1999  18+  8.7             87%       1
# 2          Avengers: Infinity War  2018  13+  8.5             84%       1
# 3              Back to the Future  1985   7+  8.5             96%       1
# 4  The Good, the Bad and the Ugly  1966  18+  8.8             97%       1
#
#   Hulu Prime Video Disney+ Type                       Directors  \
# 0    0           0       0    0               Christopher Nolan
# 1    0           0       0    0  Lana Wachowski,Lilly Wachowski
# 2    0           0       0    0         Anthony Russo,Joe Russo
# 3    0           0       0    0                 Robert Zemeckis
# 4    0           1       0    0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language Runtime movies
# 0  English,Japanese,French     148  Movie
# 1                  English     136  Movie
# 2                  English     149  Movie
# 3                  English     116  Movie
# 4                  Italian     161  Movie

# %%
shows_df2.rename(columns = {'type':'Type'}, inplace = True)

# %%
shows_df2.head()
# Out:
#               Title  Year  Age IMDb Rotten Tomatoes Netflix Hulu Prime Video  \
# 0      Breaking Bad  2008  18+  9.5             96%       1    0           0
# 1   Stranger Things  2016  16+  8.8             93%       1    0           0
# 2       Money Heist  2017  18+  8.4             91%       1    0           0
# 3          Sherlock  2010  16+  9.1             78%       1    0           0
# 4  Better Call Saul  2015  18+  8.7             97%       1    0           0
#
#   Disney+ Type shows
# 0       0    1    TV
# 1       0    1    TV
# 2       0    1    TV
# 3       0    1    TV
# 4       0    1    TV

# %%
result = pd.concat([movies_cleaned, shows_df2], ignore_index=True, sort=False)
result.head()
result.loc[(result['shows']=='TV')]
# Out:
#                                  Title  Year  Age IMDb Rotten Tomatoes  \
# 16744                     Breaking Bad  2008  18+  9.5             96%
# 16745                  Stranger Things  2016  16+  8.8             93%
# 16746                      Money Heist  2017  18+  8.4             91%
# 16747                         Sherlock  2010  16+  9.1             78%
# 16748                 Better Call Saul  2015  18+  8.7             97%
# ...                                ...   ...  ...  ...             ...
# 22350  Tut's Treasures: Hidden Secrets  2018  NaN  NaN             NaN
# 22351                 Paradise Islands  2017  NaN  NaN             NaN
# 22352                      Wild Russia  2018  NaN  NaN             NaN
# 22353                      Love & Vets  2017  NaN  NaN             NaN
# 22354         United States of Animals  2016  NaN  NaN             NaN
#
#       Netflix Hulu Prime Video Disney+ Type Directors Genres Country Language  \
# 16744       1    0           0       0    1       NaN    NaN     NaN      NaN
# 16745       1    0           0       0    1       NaN    NaN     NaN      NaN
# 16746       1    0           0       0    1       NaN    NaN     NaN      NaN
# 16747       1    0           0       0    1       NaN    NaN     NaN      NaN
# 16748       1    0           0       0    1       NaN    NaN     NaN      NaN
# ...       ...  ...         ...     ...  ...       ...    ...     ...      ...
# 22350       0    0           0       1    1       NaN    NaN     NaN      NaN
# 22351       0    0           0       1    1       NaN    NaN     NaN      NaN
# 22352       0    0           0       1    1       NaN    NaN     NaN      NaN
# 22353       0    0           0       1    1       NaN    NaN     NaN      NaN
# 22354       0    0           0       1    1       NaN    NaN     NaN      NaN
#
#       Runtime movies shows
# 16744     NaN    NaN    TV
# 16745     NaN    NaN    TV
# 16746     NaN    NaN    TV
# 16747     NaN    NaN    TV
# 16748     NaN    NaN    TV
# ...       ...    ...   ...
# 22350     NaN    NaN    TV
# 22351     NaN    NaN    TV
# 22352     NaN    NaN    TV
# 22353     NaN    NaN    TV
# 22354     NaN    NaN    TV
#
# [5611 rows x 17 columns]

# %%
len(result)
# Out:
# 22355

# %%
len(shows_df2)
# Out:
# 5611

# %%
len(movies_cleaned)
# Out:
# 16744
